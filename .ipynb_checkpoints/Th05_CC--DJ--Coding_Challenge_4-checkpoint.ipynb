# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/schwaaweb/aimlds1_05/blob/master/Th05_CC--DJ--Coding_Challenge_4.ipynb)

# %% [markdown]
# ## Coding Challenge #4
#
# In this coding challenge, we will construct a bionomial distribution based on the concepts of Bernoulli trials.
#
# In a nutshell, a Bernoulli trial is an random experiment with 2 possible outcomes i.e. Success (Yes) or Failure (No). More details on the Bernoulli trial can be found on this website:
#
# https://en.wikipedia.org/wiki/Bernoulli_trial
#
# **Problem Statement**: Let's say the DCVC venture fund invests in 100 startups. Anywhere between 0 and 100 of the startups will succeed.
#
# **Ask?** Construct a biomial distribution of getting a given number of startup successes, given that the probability of a successful startup is p = 0.1
#
#
# We will leverage a step-by-step process to construct the bionomial distribution:
#
# **Step 1**: Write a function called conduct_binomial_trails
#
# The function takes in 2 arguments and returns the number of successes (i.e. return number_successful) out of n Bionomial trials, each of which has probability p of success.
#
# During each Bionomial trial, use the np.random.random() function, which returns a random number between zero and one and compare the *returned* random number to the propability of success. If the random number is less than the probability p of success, increment the "number_successful" variable by 1 during each *iteration* of the Bionimial Trial.
#
# **Step 2**: Set up a for loop with 10000 iterations to compute the number of successes per 100 investments using the the defined function and store the results returned from each call to the function in an array.  Each call to the defined function will pass in 2 arguments: *the number of trials n* - in this case 100 - and *the probability of success p* - in this case the probability of success 0.1
#
#
# **Step 3**: # Plot the histogram with the size of the array reprensenting the # of bin and label your axes accordingly
#
# Use: plt.hist(b_array, normed=True)
#
# In this case, b_array is the array you defined in "Step 2" aboe to store the number of successes from each call to the conduct_binomial_trails function
#
# Setting *normed to true* will esnure that the counts in the array are normalized to form a probability density

# %% [markdown]
# **Step 1**: Write a function called conduct_binomial_trails
#
# The function takes in 2 arguments and returns the number of successes (i.e. return number_successful) out of n Bionomial trials, each of which has probability p of success.
#
# During each Bionomial trial, use the np.random.random() function, which returns a random number between zero and one and compare the *returned* random number to the propability of success. If the random number is less than the probability p of success, increment the "number_successful" variable by 1 during each *iteration* of the Bionimial Trial.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100

# %%
def conduct_binomial_trials(p,n):
    number_successful = 0
    for i in range(n):
        if np.random.random() < p:
            number_successful += 1
            #print('success')
        #else:
            #print('failed')
    return number_successful

# %%
p0 = 0.1 # chances of success
n0 = 100 # number of attempts
conduct_binomial_trials(p0,n0)
# Out:
# 9

# %% [markdown]
# **Step 2**: Set up a for loop with 10000 iterations to compute the number of successes per 100 investments using the the defined function and store the results returned from each call to the function in an array.  Each call to the defined function will pass in 2 arguments: *the number of trials n* - in this case 100 - and *the probability of success p* - in this case the probability of success 0.1

# %%
p1 = 0.1 # chances of success
n1 = 100 # number of attempts
trials = []
for i in range(10000):
    t = conduct_binomial_trials(p1,n1)
    trials.append(t)
print('\n',trials)
# Out:
#  [4, 6, 11, 14, 11, 8, 11, 10, 11, 18, 9, 12, 11, 8, 9, 7, 12, 6, 10, 7, 10, 9, 17, 9, 10, 16, 6, 10, 8, 12, 7, 8, 11, 7, 10, 10, 6, 11, 7, 8, 13, 8, 10, 7, 8, 6, 14, 19, 10, 4, 15, 5, 15, 12, 8, 7, 10, 12, 6, 13, 12, 16, 10, 16, 9, 15, 11, 8, 9, 11, 11, 11, 14, 13, 6, 9, 12, 10, 8, 10, 11, 9, 7, 11, 9, 12, 15, 13, 7, 11, 7, 12, 8, 7, 10, 10, 11, 7, 12, 15, 9, 9, 8, 10, 6, 9, 10, 13, 12, 10, 10, 12, 10, 9, 8, 11, 9, 7, 7, 12, 9, 10, 8, 7, 3, 9, 13, 9, 14, 10, 7, 12, 6, 9, 8, 10, 13, 7, 7, 12, 7, 7, 7, 11, 11, 13, 8, 10, 12, 5, 11, 14, 5, 11, 7, 9, 11, 8, 10, 12, 7, 15, 11, 8, 14, 8, 10, 10, 13, 8, 9, 9, 10, 10, 14, 8, 13, 14, 8, 14, 8, 9, 10, 7, 11, 13, 10, 12, 13, 9, 7, 7, 13, 15, 6, 13, 10, 7, 15, 11, 12, 12, 8, 6, 11, 15, 12, 12, 10, 7, 6, 9, 10, 11, 7, 14, 9, 11, 9, 6, 10, 12, 10, 12, 3, 11, 7, 11, 13, 11, 11, 14, 11, 9, 13, 6, 11, 12, 10, 10, 10, 8, 10, 11, 11, 10, 14, 8, 16, 8, 9, 11, 10, 6, 7, 6, 10, 7, 13, 9, 9, 5, 9, 9, 11, 4, 11, 10, 11, 6, 12, 11, 7, 13, 15, 11, 11, 9, 10, 10, 14, 10, 6, 8, 16, 14, 9, 13, 15, 8, 9, 10, 6, 16, 8, 12, 12, 13, 8, 8, 16, 4, 9, 9, 8, 9, 10, 12, 8, 7, 10, 6, 7, 4, 12, 9, 12, 12, 13, 9, 18, 12, 7, 11, 6, 10, 10, 6, 12, 12, 6, 11, 12, 14, 9, 7, 12, 10, 9, 8, 8, 4, 11, 9, 11, 6, 9, 14, 12, 11, 10, 11, 10, 11, 14, 10, 6, 9, 14, 13, 9, 10, 10, 14, 9, 7, 5, 14, 11, 9, 10, 8, 13, 7, 9, 15, 8, 10, 9, 10, 15, 11, 11, 15, 10, 18, 14, 18, 6, 16, 7, 7, 5, 12, 5, 13, 6, 8, 13, 11, 5, 10, 10, 6, 8, 12, 8, 8, 8, 10, 8, 10, 8, 6, 17, 9, 10, 12, 9, 15, 7, 12, 7, 9, 12, 12, 8, 6, 12, 10, 8, 7, 8, 15, 8, 12, 13, 12, 12, 12, 8, 12, 8, 12, 6, 17, 3, 12, 14, 13, 5, 9, 12, 12, 9, 13, 10, 9, 10, 11, 8, 9, 8, 15, 11, 12, 13, 12, 16, 8, 9, 13, 18, 10, 5, 12, 11, 5, 16, 10, 9, 13, 7, 11, 12, 11, 7, 8, 13, 13, 7, 9, 9, 12, 11, 12, 9, 9, 8, 9, 12, 13, 10, 7, 14, 9, 14, 7, 12, 9, 11, 3, 8, 9, 15, 8, 9, 14, 5, 12, 11, 14, 9, 11, 10, 10, 9, 9, 10, 5, 13, 10, 16, 12, 14, 17, 12, 8, 10, 16, 12, 7, 7, 9, 5, 10, 8, 17, 11, 11, 8, 9, 6, 9, 9, 12, 10, 7, 12, 10, 10, 8, 6, 10, 14, 8, 14, 14, 8, 9, 9, 11, 13, 11, 8, 10, 13, 10, 11, 9, 2, 5, 14, 13, 11, 9, 7, 8, 6, 7, 8, 9, 14, 8, 9, 12, 14, 9, 9, 9, 10, 12, 6, 6, 6, 13, 14, 13, 13, 10, 10, 19, 3, 8, 13, 6, 7, 6, 13, 6, 12, 10, 12, 7, 8, 9, 5, 11, 14, 11, 10, 7, 10, 14, 11, 12, 9, 6, 10, 14, 5, 18, 16, 2, 9, 10, 6, 15, 13, 9, 9, 11, 8, 6, 14, 10, 11, 6, 4, 16, 6, 8, 12, 9, 8, 5, 13, 15, 12, 14, 9, 10, 10, 16, 12, 6, 8, 6, 10, 10, 11, 12, 10, 9, 14, 8, 11, 10, 9, 7, 7, 17, 10, 5, 15, 10, 7, 9, 15, 9, 7, 9, 13, 6, 10, 8, 6, 10, 8, 12, 9, 12, 6, 7, 10, 6, 13, 11, 11, 13, 5, 13, 10, 16, 11, 6, 9, 9, 14, 12, 7, 9, 11, 9, 16, 13, 15, 7, 8, 9, 8, 9, 13, 6, 10, 9, 15, 7, 4, 9, 8, 8, 6, 17, 9, 12, 15, 13, 13, 15, 11, 12, 10, 3, 7, 8, 10, 12, 12, 11, 10, 9, 6, 10, 12, 10, 9, 8, 11, 6, 10, 4, 11, 13, 10, 16, 9, 7, 10, 8, 13, 11, 9, 11, 10, 10, 5, 12, 9, 9, 7, 11, 12, 10, 9, 8, 14, 17, 10, 13, 8, 9, 9, 9, 10, 9, 11, 9, 10, 12, 7, 11, 10, 8, 12, 8, 11, 14, 6, 11, 10, 12, 7, 15, 13, 10, 8, 10, 8, 12, 6, 14, 7, 8, 7, 6, 13, 6, 15, 8, 15, 10, 7, 6, 13, 9, 11, 11, 12, 3, 11, 7, 5, 8, 12, 12, 6, 9, 13, 10, 12, 14, 7, 11, 6, 14, 5, 13, 8, 11, 10, 16, 6, 10, 10, 13, 7, 12, 7, 7, 16, 11, 13, 6, 6, 10, 6, 9, 6, 8, 13, 5, 10, 9, 10, 9, 6, 3, 11, 11, 9, 10, 8, 10, 8, 14, 7, 5, 7, 9, 8, 14, 13, 5, 11, 10, 17, 11, 6, 5, 12, 9, 11, 10, 15, 17, 10, 13, 8, 10, 16, 11, 12, 8, 9, 11, 8, 7, 10, 5, 11, 6, 9, 4, 9, 11, 12, 5, 8, 8, 11, 8, 7, 3, 10, 8, 7, 20, 10, 14, 8, 11, 8, 7, 12, 4, 12, 8, 4, 6, 14, 10, 10, 10, 7, 16, 8, 9, 13, 13, 10, 7, 11, 10, 4, 10, 12, 11, 12, 9, 7, 10, 14, 5, 12, 9, 7, 15, 6, 8, 12, 13, 7, 16, 14, 15, 9, 7, 7, 12, 12, 11, 7, 4, 12, 6, 14, 10, 12, 8, 15, 7, 15, 15, 9, 11, 11, 13, 16, 11, 7, 8, 13, 16, 13, 16, 10, 14, 11, 8, 7, 6, 12, 13, 10, 13, 10, 12, 10, 12, 12, 15, 11, 11, 9, 11, 8, 8, 12, 13, 11, 14, 10, 6, 7, 9, 10, 12, 9, 14, 17, 10, 14, 14, 16, 10, 5, 13, 15, 11, 9, 8, 15, 8, 10, 10, 9, 12, 14, 10, 13, 10, 9, 5, 8, 8, 5, 10, 13, 13, 7, 6, 7, 12, 10, 5, 7, 8, 10, 8, 8, 6, 15, 13,  ...

# %% [markdown]
# **Step 3**: # Plot the histogram with the size of the array reprensenting the # of bin and label your axes accordingly
#
# Use: plt.hist(b_array, normed=True)
#
# In this case, b_array is the array you defined in "Step 2" aboe to store the number of successes from each call to the conduct_binomial_trails function
#
# Setting *normed to true* will esnure that the counts in the array are normalized to form a probability density

# %%
trialsa = np.array(trials)

# %%
plt.hist(trials,bins=100);

# %%
# !git status
